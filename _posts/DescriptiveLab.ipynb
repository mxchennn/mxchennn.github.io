# %% [markdown]
# ---
# descriptive lab
# ---

# %%
import pandas as pd
import seaborn as sns
import math as math
survey = pd.read_csv("/Users/mingxingchen/Desktop/ArtOfData/DescriptiveLab/2017-fCC-New-Coders-Survey-Data.csv")

# %% [markdown]
# for this lab i worked with the "new coder survey" dataset
# the first variable i looked at was the age of the participants
# the mean age was around 28 years old

# %%
pd.DataFrame.describe(survey)
# Out:
#                 Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo  \
# count  15367.000000      17709.000000     1069.000000        1079.000000
# mean      27.691872          0.062002        0.699719           0.305839
# std        8.559239          0.241167        0.458594           0.460975
# min        0.000000          0.000000        0.000000           0.000000
# 25%       22.000000          0.000000        0.000000           0.000000
# 50%       26.000000          0.000000        1.000000           0.000000
# 75%       32.000000          0.000000        1.000000           1.000000
# max       90.000000          1.000000        1.000000           1.000000
#
#        BootcampRecommend  ChildrenNumber  CodeEventConferences  \
# count        1073.000000     2314.000000                1609.0
# mean            0.818267        1.832325                   1.0
# std             0.385805        0.972813                   0.0
# ...

# %% [markdown]
# when i looked at a histogram showing the distribution of ages, i saw that the graph was skewed to the right

# %%
sns.histplot(data = survey, x = ages)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-937302f48581> in <module>
# ----> 1 sns.histplot(data = survey, x = ages)
#
# NameError: name 'ages' is not defined

# %% [markdown]
# then, i looked at the relationship between age and city population
# i generated a bar plot that showed that older people tended to live in less populated areas than younger people, this makes sense because older people would probably live in more rural areas.

# %%
CityPopulations = survey['CityPopulation']
ages = survey['Age']

sns.boxplot(x = CityPopulations, y = ages, data = survey, order = ("less than 100,000", "between 100,000 and 1 million", "more than 1 million"), palette=(sns.color_palette(n_colors=1)))
# Out:
# <AxesSubplot:xlabel='CityPopulation', ylabel='Age'>
